# %%
import HeatmapTools as ht

# %%
df=ht.cargar_preparar_archivos("Sham")
df
# Out:
#          Time  Centre position X  Centre position Y  In Brazo Abierto  \
# 0        0.26              287.0              256.0                 1
# 1        0.38              287.0              259.0                 1
# 2        0.55              288.0              267.0                 1
# 3        0.67              286.0              273.0                 1
# 4        0.79              285.0              277.0                 1
# ...       ...                ...                ...               ...
# 20443  299.50              329.0              315.0                 0
# 20444  299.62              329.0              314.0                 0
# 20445  299.75              327.0              314.0                 0
# 20446  299.86              328.0              314.0                 0
# 20447  299.97              329.0              314.0                 0
#
#        In Brazo Cerrado  In centro+                     Source_file
# 0                     0           0  20LabCruz_Pre_Post_EE5_RAD.csv
# 1                     0           0  20LabCruz_Pre_Post_EE5_RAD.csv
# 2                     0           0  20LabCruz_Pre_Post_EE5_RAD.csv
# 3                     0           0  20LabCruz_Pre_Post_EE5_RAD.csv
# 4                     0           0  20LabCruz_Pre_Post_EE5_RAD.csv
# ...                 ...         ...                             ...
# 20443                 1           0  26LabCruz_Pre_Post_EE5_RAD.csv
# 20444                 1           0  26LabCruz_Pre_Post_EE5_RAD.csv
# 20445                 1           0  26LabCruz_Pre_Post_EE5_RAD.csv
# 20446                 1           0  26LabCruz_Pre_Post_EE5_RAD.csv
# 20447                 1           0  26LabCruz_Pre_Post_EE5_RAD.csv
#
# [20448 rows x 7 columns]

# %%
x=df['Centre position X']
y=df['Centre position Y']
title="Heatmap Sham"
output_file='heatmapSham_nuevo.png'
maze_image_path='laberinto.png'

# %%
ht.plot_heatmap_overlay(x,y,title,output_file,maze_image_path)
