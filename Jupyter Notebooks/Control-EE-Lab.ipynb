# %%
import HeatmapTools as ht

# %%
df=ht.cargar_preparar_archivos("Control-EE-Post")
df
# Out:
#          Time  Centre position X  Centre position Y Source_file
# 0        0.21                164                252      23.csv
# 1        0.33                160                252      23.csv
# 2        0.44                160                252      23.csv
# 3        0.55                159                252      23.csv
# 4        0.66                160                252      23.csv
# ...       ...                ...                ...         ...
# 30686  299.44                412                248      13.csv
# 30687  299.54                410                247      13.csv
# 30688  299.66                410                247      13.csv
# 30689  299.77                410                247      13.csv
# 30690  299.89                410                247      13.csv
#
# [30691 rows x 4 columns]

# %%
x=df['Centre position X']
y=df['Centre position Y']
title="Heatmap Control-EE"
output_file='heatmapControl-EE_nuevo.png'
maze_image_path='laberinto.png'

# %%
ht.plot_heatmap_overlay(x,y,title,output_file,maze_image_path)
